# %%
# %load_ext autoreload
# %autoreload 2
import torch
import eq
import matplotlib.pyplot as plt
import numpy as np
from tqdm.notebook import trange, tqdm

from torch.utils.tensorboard import SummaryWriter
import datetime

import warnings
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print(eq.data.default_catalogs_dir)
# Out:
# /home/zekai/repos/recast/data

# %%
catalog = eq.catalogs.ANSS_MultiCatalog(num_sequences=10000,
    t_end_days=4*365,
    mag_completeness=4.5,
    minimum_mainshock_mag=6.0,)
# Out:
# Loading existing catalog from /home/zekai/repos/recast/data/ANSS_MultiCatalog.

# %%
print("Train sequence:")
print(catalog.train[0])
print("\nValidation sequence:")
print(catalog.val[0])
print("\nTest sequence:")
print(catalog.test[0])
# Out:
# Train sequence:
# Sequence(
#   inter_times: [1708],
#   arrival_times: [1707],
#   t_start: 0.0,
#   t_end: 1460.0,
#   t_nll_start: 0.0,
#   mag: [1707],
#   mag_bounds: [2],
#   mag_nll_bounds: [2],
#   extra_feat: [1707, 1]
# )
#
# Validation sequence:
# Sequence(
#   inter_times: [270],
#   arrival_times: [269],
#   t_start: 0.0,
#   t_end: 1008.839,
#   t_nll_start: 0.0,
#   mag: [269],
#   mag_bounds: [2],
#   mag_nll_bounds: [2],
#   extra_feat: [269, 1]
# )
#
# Test sequence:
# Sequence(
#   inter_times: [1038],
#   arrival_times: [1037],
#   t_start: 0.0,
#   t_end: 1460.0,
#   t_nll_start: 0.0,
#   mag: [1037],
#   mag_bounds: [2],
#   mag_nll_bounds: [2],
#   extra_feat: [1037, 1]
# )

# %%
eq.visualization.visualize_sequence(catalog.test[0], show_nll=True)
# Out:
# <Axes: xlabel='Time (days)', ylabel='Magnitude'>

# %% [markdown]
# ## Training the model

# %%
batch_size = 32
dl_train = catalog.train.get_dataloader(batch_size=batch_size)
dl_val = catalog.val.get_dataloader(batch_size=batch_size)
dl_test = catalog.test.get_dataloader(batch_size=batch_size)

# %%
#!nvidia-smi
gpu_number = 0
device = torch.device(f"cuda:{gpu_number}")
print(f"using {device}")
# Out:
# using cuda:0

# %%
model = eq.models.RecurrentTPP()
model = model.to(device)

# %%
epochs = 100
avg_train_loss_list =[]
avg_val_loss_list = []

effective_batch_size = 32
M = effective_batch_size // batch_size

optimizer = torch.optim.Adam(model.parameters(), lr=3e-3)
optimizer.zero_grad()

now = datetime.datetime.now()
writer = SummaryWriter(f"experiments/recurrent_{now}")

num_train_iters_in_one_epoch = len(dl_train)

for epoch in trange(epochs):
    running_training_loss = []
    model.train()
    for i, data in enumerate(dl_train):
        data = data.to(device)
        nll = model.nll_loss(data).mean() / M
        nll.backward()
        running_training_loss.append(nll.item())
        writer.add_scalar("training_loss_per_step", nll.item() * M, i + epoch * num_train_iters_in_one_epoch)
        for name, param in model.named_parameters():
            if param.grad is not None:
                writer.add_scalar(f"{name}_accumulated_gradient_norm_per_step", torch.norm(param.grad).item(), i + epoch * num_train_iters_in_one_epoch)

        if i % M == M - 1:
            torch.nn.utils.clip_grad_value_(model.parameters(), 0.5)
            optimizer.step()
            optimizer.zero_grad()
        
    model.eval()
    with torch.no_grad():
        running_val_loss = []
        for i, data in enumerate(dl_val):
            data = data.to(device)
            nll = model.nll_loss(data).mean()
            running_val_loss.append(nll.item())

    avg_train_loss_list.append(np.mean(running_training_loss))
    avg_val_loss_list.append(np.mean(running_val_loss))
    writer.add_scalar("avg_training_loss_per_epoch", np.mean(running_training_loss), epoch)
    writer.add_scalar("avg_validation_loss_per_epoch", np.mean(running_val_loss), epoch)
writer.close()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/zekai/repos/recast/notebooks/Zekai/recurrent_attention/training_recurrent.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/home/zekai/repos/recast/notebooks/Zekai/recurrent_attention/training_recurrent.ipynb#X12sZmlsZQ%3D%3D?line=18'>19</a> for i, data in enumerate(dl_train):
#      <a href='vscode-notebook-cell:/home/zekai/repos/recast/notebooks/Zekai/recurrent_attention/training_recurrent.ipynb#X12sZmlsZQ%3D%3D?line=19'>20</a>     data = data.to(device)
# ---> <a href='vscode-notebook-cell:/home/zekai/repos/recast/notebooks/Zekai/recurrent_attention/training_recurrent.ipynb#X12sZmlsZQ%3D%3D?line=20'>21</a>     nll = model.nll_loss(data).mean() / M
#      <a href='vscode-notebook-cell:/home/zekai/repos/recast/notebooks/Zekai/recurrent_attention/training_recurrent.ipynb#X12sZmlsZQ%3D%3D?line=21'>22</a>     nll.backward()
#      <a href='vscode-notebook-cell:/home/zekai/repos/recast/notebooks/Zekai/recurrent_attention/training_recurrent.ipynb#X12sZmlsZQ%3D%3D?line=22'>23</a>     running_training_loss.append(nll.item())
#
# File ~/repos/recast/eq/models/recurrent.py:163, in RecurrentTPP.nll_loss(self, batch)
#     161 context = self.get_context(batch)  # (B, L, C)
#     162 # Inter-event times
# --> 163 inter_time_dist = self.get_inter_time_dist(context)
#     164 log_pdf = inter_time_dist.log_prob(batch.inter_times.clamp_min(1e-10))  # (B, L)
#     165 log_like = (log_pdf * batch.mask).sum(-1)
#
# File ~/repos/recast/eq/models/recurrent.py:137, in RecurrentTPP.get_inter_time_dist(self, context)
#     135 shape = F.softplus(shape.clamp_min(-5.0))
#     136 weight_logits = F.log_softmax(weight_logits, dim=-1)
# --> 137 component_dist = dist.Weibull(scale=scale, shape=shape)
#     138 mixture_dist = Categorical(logits=weight_logits)
#     139 return dist.MixtureSameFamily(
#     140     mixture_distribution=mixture_dist,
#     141     component_distribution=component_dist,
#     142 )
#
# File ~/repos/recast/eq/distributions/weibull.py:17, in Weibull.__init__(self, scale, shape, eps, validate_args)
#      15 self.eps = eps
#      16 batch_shape = self.scale.shape
# ---> 17 super().__init__(batch_shape, validate_args=validate_args)
#
# File ~/miniconda3/envs/eq/lib/python3.11/site-packages/torch/distributions/distribution.py:68, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      66         valid = constraint.check(value)
#      67         if not valid.all():
# ---> 68             raise ValueError(
#      69                 f"Expected parameter {param} "
#      70                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      71                 f"of distribution {repr(self)} "
#      72                 f"to satisfy the constraint {repr(constraint)}, "
#      73                 f"but found invalid values:\n{value}"
#      74             )
#      75 super().__init__()
#
# ValueError: Expected parameter scale (Tensor of shape (32, 3363, 32)) of distribution Weibull(scale: torch.Size([32, 3363, 32]), shape: torch.Size([32, 3363, 32])) to satisfy the constraint GreaterThan(lower_bound=0.0), but found invalid values:
# tensor([[[1.1497, 1.0238, 1.9644,  ..., 0.7896, 0.7573, 0.8204],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#         [[1.1497, 1.0238, 1.9644,  ..., 0.7896, 0.7573, 0.8204],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#         [[1.1497, 1.0238, 1.9644,  ..., 0.7896, 0.7573, 0.8204],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#         ...,
#
#         [[1.1497, 1.0238, 1.9644,  ..., 0.7896, 0.7573, 0.8204],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#         [[1.1497, 1.0238, 1.9644,  ..., 0.7896, 0.7573, 0.8204],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan]],
#
#         [[1.1497, 1.0238, 1.9644,  ..., 0.7896, 0.7573, 0.8204],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          ...,
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan],
#          [   nan,    nan,    nan,  ...,    nan,    nan,    nan]]],
#        device='cuda:0', grad_fn=<SoftplusBackward0>)

# %%
model.eval()
with torch.no_grad():
    running_test_loss = []
    for i, data in enumerate(dl_test):
        data = data.to(device)
        nll = model.nll_loss(data).mean()
        running_test_loss.append(nll.item())
print(f"avg test loss: {np.mean(running_test_loss)}")
# Out:
# avg test loss: 0.41284275102236917

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(np.arange(0, epochs), avg_val_loss_list, label="avg val loss")
ax.plot(np.arange(0, epochs), avg_train_loss_list, label="avg train loss")
ax.set_xlabel("epoch")
ax.set_ylabel("nll loss")
ax.legend()
ax.set_title("Avg Training and Validation Loss, RecurrentTPP")
plt.show()

# %%
torch.save(model, "trained_recurrent_tpp")
