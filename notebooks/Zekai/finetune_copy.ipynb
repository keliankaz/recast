# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2

import pytorch_lightning as pl
import pytorch_lightning.callbacks as pl_callbacks
import torch
import numpy as np
import matplotlib.pyplot as plt
import pickle

from tqdm import tqdm, trange

import eq
from eq.models import RecurrentTPP
from eq.catalogs.Combined_Catalog import CombinedCatalog

from eq.data import Catalog, InMemoryDataset, Sequence, default_catalogs_dir

# %%
device="cuda"

# %%
raise Exception("unpickle it!")
np.random.seed(42)
test_catalog = eq.catalogs.ANSS_MultiCatalog(    
    num_sequences=20000,
    radius_kilometers = 200,
    t_end_days=4*365,
    mag_completeness=4.5,
    minimum_mainshock_mag=6.0,
)

assert [len(seq.inter_times) for seq in test_catalog.test][:10] == [44, 22, 16, 54, 84, 8, 8, 201, 383, 30]
with open("test_catalog", "wb") as f:
    pickle.dump(test_catalog, f)

test_dl = test_catalog.test.get_dataloader()
with open("test_dl", "wb") as f:
    pickle.dump(test_dl, f)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /home/zekai/repos/recast/notebooks/Zekai/finetune.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/home/zekai/repos/recast/notebooks/Zekai/finetune.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> raise Exception("unpickle it!")
#       <a href='vscode-notebook-cell:/home/zekai/repos/recast/notebooks/Zekai/finetune.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> np.random.seed(42)
#       <a href='vscode-notebook-cell:/home/zekai/repos/recast/notebooks/Zekai/finetune.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> test_catalog = eq.catalogs.ANSS_MultiCatalog(
#       <a href='vscode-notebook-cell:/home/zekai/repos/recast/notebooks/Zekai/finetune.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a>     num_sequences=20000,
#       <a href='vscode-notebook-cell:/home/zekai/repos/recast/notebooks/Zekai/finetune.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a>     radius_kilometers = 200,
#    (...)
#       <a href='vscode-notebook-cell:/home/zekai/repos/recast/notebooks/Zekai/finetune.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a>     minimum_mainshock_mag=6.0,
#       <a href='vscode-notebook-cell:/home/zekai/repos/recast/notebooks/Zekai/finetune.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> )
#
# Exception: unpickle it!

# %%
with open("test_dl", "rb") as f:
    test_dl = pickle.load(f)

# %%
def train(model, optimizer, dl_train, dl_val, epochs, best_model_path):
    avg_train_loss_list = []
    avg_val_loss_list = []
    best_val_loss = float('inf')
    for epoch in trange(epochs):
        running_train_loss = []
        model.train()
        for i, data in enumerate(dl_train):
            data = data.to(device)
            optimizer.zero_grad()
            nll = model.nll_loss(data).mean()
            nll.backward()
            optimizer.step()
            running_train_loss.append(nll.item())
                    
        model.eval()
        with torch.no_grad():
            running_val_loss = []
            for i, data in enumerate(dl_val):
                data = data.to(device)
                nll = model.nll_loss(data).mean()
                running_val_loss.append(nll.item())

        avg_val_loss = np.mean(running_val_loss)
        avg_train_loss = np.mean(running_train_loss)
        avg_train_loss_list.append(avg_train_loss)
        avg_val_loss_list.append(avg_val_loss)

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            torch.save(model.state_dict(), best_model_path)
    model.load_state_dict(torch.load(best_model_path))
    return model, avg_train_loss_list, avg_val_loss_list

def test(model, dl_test):
    model.eval()
    with torch.no_grad():
        nll_loss_list = []
        for i, data in enumerate(dl_test):
            data = data.to(device)
            nll = model.nll_loss(data).mean()
            nll_loss_list.append(nll.item())
        print("avg nll loss: ", np.mean(nll_loss_list))
    return np.mean(nll_loss_list)

# %%
catalogs = []
anss = eq.catalogs.ANSS_MultiCatalog(    
    num_sequences=100,
    t_end_days=1*365,
    mag_completeness=4.5,
    minimum_mainshock_mag=6.0,
    include_depth=False
)
catalogs.append(anss)
scedc = eq.catalogs.SCEDC(include_depth=False)
catalogs.append(scedc)
white = eq.catalogs.White()
catalogs.append(white)
# Out:
# Loading existing catalog from /home/zekai/repos/recast/data/ANSS_MultiCatalog.
# Loading existing catalog from /home/zekai/repos/recast/data/SCEDC.
# Loading existing catalog from /home/zekai/repos/recast/data/White.
# /home/zekai/repos/recast/eq/data/sequence.py:213: UserWarning: Found 1 zero inter-event times in the sequence. This violates fundamental assumptions of TPP models and may lead to incorrect log-likelihood values.
#   warnings.warn(

# %% [markdown]
# ## Sanity Check: train on the common test catalog

# %%
with open("test_catalog", "rb") as f:
    test_catalog = pickle.load(f)

batch_size = 32
test_catalog_train_dl = test_catalog.train.get_dataloader(batch_size=batch_size)
test_catalog_val_dl = test_catalog.val.get_dataloader(batch_size=batch_size)

T = test_catalog.train.sequences[0].t_end
N = np.mean([len(seq) for seq in test_catalog.train.sequences])
tau_mean = T/N

model = RecurrentTPP(
    context_size=32,
    num_components=32,
    rnn_type="LSTM",
    dropout_proba=0.1,
    tau_mean=tau_mean,
    learning_rate=0.005
)

model = model.to(device)

optimizer = torch.optim.AdamW(
        model.parameters(), 
        lr=0.005, 
        betas=(0.99, 0.999), 
        weight_decay=0.005
    )

epochs = 50

# %%
model, avg_train_loss_list, avg_val_loss_list = train(
    model=model, 
    optimizer=optimizer, 
    dl_train=test_catalog_train_dl, 
    dl_val=test_catalog_val_dl,
    epochs=epochs,
    best_model_path="temp"
)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]/home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1], which does not match the required output shape [32, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 783, 1], which does not match the required output shape [32, 783, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 831, 1], which does not match the required output shape [32, 831, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 486, 1], which does not match the required output shape [32, 486, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1048, 1], which does not match the required output shape [32, 1048, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 570, 1], which does not match the required output shape [32, 570, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 718, 1], which does not match the required output shape [32, 718, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 954, 1], which does not match the required output shape [32, 954, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 620, 1], which does not match the required output shape [32, 620, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 903, 1], which does not match the required output shape [32, 903, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 433, 1], which does not match the required output shape [32, 433, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 897, 1], which does not match the required output shape [32, 897, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 500, 1], which does not match the required output shape [32, 500, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 793, 1], which does not match the required output shape [32, 793, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 906, 1], which does not match the required output shape [32, 906, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 881, 1], which does not match the required output shape [32, 881, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 394, 1], which does not match the required output shape [32, 394, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 549, 1], which does not match the required output shape [32, 549, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 485, 1], which does not match the required output shape [32, 485, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1109, 1], which does not match the required output shape [32, 1109, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 571, 1], which does not match the required output shape [32, 571, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 470, 1], which does not match the required output shape [32, 470, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1033, 1], which does not match the required output shape [32, 1033, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 710, 1], which does not match the required output shape [32, 710, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1002, 1], which does not match the required output shape [32, 1002, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1153, 1], which does not match the required output shape [32, 1153, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 830, 1], which does not match the required output shape [32, 830, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 468, 1], which does not match the required output shape [32, 468, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 562, 1], which does not match the required output shape [32, 562, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 385, 1], which does not match the required output shape [32, 385, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 575, 1], which does not match the required output shape [32, 575, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 998, 1], which does not match the required output shape [32, 998, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 916, 1], which does not match the required output shape [32, 916, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 858, 1], which does not match the required output shape [32, 858, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 909, 1], which does not match the required output shape [32, 909, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 589, 1], which does not match the required output shape [32, 589, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 412, 1], which does not match the required output shape [32, 412, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1015, 1], which does not match the required output shape [32, 1015, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 378, 1], which does not match the required output shape [32, 378, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 621, 1], which does not match the required output shape [32, 621, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1199, 1], which does not match the required output shape [32, 1199, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 616, 1], which does not match the required output shape [32, 616, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 735, 1], which does not match the required output shape [32, 735, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 983, 1], which does not match the required output shape [32, 983, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 399, 1], which does not match the required output shape [32, 399, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1041, 1], which does not match the required output shape [32, 1041, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 741, 1], which does not match the required output shape [32, 741, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 915, 1], which does not match the required output shape [32, 915, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 919, 1], which does not match the required output shape [32, 919, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 540, 1], which does not match the required output shape [32, 540, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 512, 1], which does not match the required output shape [32, 512, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 960, 1], which does not match the required output shape [32, 960, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 639, 1], which does not match the required output shape [32, 639, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 980, 1], which does not match the required output shape [32, 980, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1008, 1], which does not match the required output shape [32, 1008, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1126, 1], which does not match the required output shape [32, 1126, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 416, 1], which does not match the required output shape [32, 416, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 892, 1], which does not match the required output shape [32, 892, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 982, 1], which does not match the required output shape [32, 982, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 516, 1], which does not match the required output shape [32, 516, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 976, 1], which does not match the required output shape [32, 976, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 946, 1], which does not match the required output shape [32, 946, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 847, 1], which does not match the required output shape [32, 847, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1131, 1], which does not match the required output shape [32, 1131, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1164, 1], which does not match the required output shape [32, 1164, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1066, 1], which does not match the required output shape [32, 1066, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 545, 1], which does not match the required output shape [32, 545, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 926, 1], which does not match the required output shape [32, 926, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 696, 1], which does not match the required output shape [32, 696, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1176, 1], which does not match the required output shape [32, 1176, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# ...
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 490, 1], which does not match the required output shape [32, 490, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 462, 1], which does not match the required output shape [32, 462, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 652, 1], which does not match the required output shape [32, 652, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1163, 1], which does not match the required output shape [32, 1163, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 958, 1], which does not match the required output shape [32, 958, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 555, 1], which does not match the required output shape [32, 555, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1177, 1], which does not match the required output shape [32, 1177, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 502, 1], which does not match the required output shape [32, 502, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 806, 1], which does not match the required output shape [32, 806, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 788, 1], which does not match the required output shape [32, 788, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 863, 1], which does not match the required output shape [32, 863, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1188, 1], which does not match the required output shape [32, 1188, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 657, 1], which does not match the required output shape [32, 657, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 803, 1], which does not match the required output shape [32, 803, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 943, 1], which does not match the required output shape [32, 943, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 911, 1], which does not match the required output shape [32, 911, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 643, 1], which does not match the required output shape [32, 643, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 883, 1], which does not match the required output shape [32, 883, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 814, 1], which does not match the required output shape [32, 814, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1035, 1], which does not match the required output shape [32, 1035, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 286, 1], which does not match the required output shape [32, 286, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 598, 1], which does not match the required output shape [32, 598, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 961, 1], which does not match the required output shape [32, 961, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# 100%|██████████| 50/50 [01:55<00:00,  2.31s/it]

# %%
plt.plot(np.arange(epochs), avg_train_loss_list, label="train loss")
plt.plot(np.arange(epochs), avg_val_loss_list, label="val loss")
plt.xlabel("epochs")
plt.ylabel("nll loss")
plt.title("Training Curve, Direct Training")
plt.legend()
plt.show()

# %%
avg_test_loss = test(model=model, dl_test=test_dl)
# Out:
# avg nll loss:  0.15901731122705678

# %%
model.load_state_dict(torch.load("temp"))
test(model=model, dl_test=white.test.get_dataloader())
# Out:
# avg nll loss:  -85.99324274416323
# -85.99324274416323

# %%
model.load_state_dict(torch.load("temp"))
test(model=model, dl_test=scedc.test.get_dataloader())
# Out:
# avg nll loss:  -405.20597926409
# -405.20597926409

# %% [markdown]
# ## Direct Training

# %%
batch_size = 32
anss_train_dl = anss.train.get_dataloader(batch_size=batch_size)
anss_val_dl = anss.val.get_dataloader(batch_size=batch_size)

T = anss.train.sequences[0].t_end
N = np.mean([len(seq) for seq in anss.train.sequences])
tau_mean = T/N

model = RecurrentTPP(
    context_size=32,
    num_components=32,
    rnn_type="LSTM",
    dropout_proba=0.1,
    tau_mean=tau_mean,
    learning_rate=0.005
)

model = model.to(device)

optimizer = torch.optim.AdamW(
        model.parameters(), 
        lr=0.005, 
        betas=(0.99, 0.999), 
        weight_decay=0.005
    )

epochs = 200
best_model_path = "direct_training_best_model"

# %%
model, avg_train_loss_list, avg_val_loss_list = train(
    model=model, 
    optimizer=optimizer, 
    dl_train=anss_train_dl, 
    dl_val=anss_val_dl,
    epochs=epochs,
    best_model_path=best_model_path
)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]/home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 406, 1], which does not match the required output shape [32, 406, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [28, 1], which does not match the required output shape [28, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [28, 982, 1], which does not match the required output shape [28, 982, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# 100%|██████████| 200/200 [00:03<00:00, 62.83it/s]

# %%
plt.plot(np.arange(epochs), avg_train_loss_list, label="train loss")
plt.plot(np.arange(epochs), avg_val_loss_list, label="val loss")
plt.legend()
plt.show()

# %%
avg_test_loss = test(model=model, dl_test=test_dl)
# Out:
# avg nll loss:  0.1725792881622192

# %% [markdown]
# ## Pretrain

# %%
# pretrain on mixture dataset, 0.34 0.33 0.33 ratio
batch_size = 32
combined_catalog = CombinedCatalog(catalogs, [0.34, 0.33, 0.33])
conbined_train_dl = combined_catalog.combined_info["combined_train"].get_dataloader(batch_size=batch_size)
combined_val_dl = combined_catalog.combined_info["combined_val"].get_dataloader(batch_size=batch_size)

T = combined_catalog.combined_info['combined_train'].sequences[0].t_end
N = np.mean([len(seq) for seq in combined_catalog.combined_info['combined_train'].sequences])
tau_mean = T/N

model = RecurrentTPP(
    context_size=32,
    num_components=32,
    rnn_type="LSTM",
    dropout_proba=0.1,
    tau_mean=tau_mean,
    learning_rate=0.005
)

model = model.to(device)

optimizer = torch.optim.AdamW(
        model.parameters(), 
        lr=0.005, 
        betas=(0.99, 0.999), 
        weight_decay=0.005
    )

epochs = 200
best_model_path = "pretrain_best_model"
# Out:
# Loading existing catalog from /home/zekai/repos/recast/notebooks/Zekai/combined.
# 203
# 69.0
# 60
# 67.0
# 67
# 67.0
# 53
# /home/zekai/repos/recast/eq/data/sequence.py:213: UserWarning: Found 2 zero inter-event times in the sequence. This violates fundamental assumptions of TPP models and may lead to incorrect log-likelihood values.
#   warnings.warn(

# %%
model, avg_train_loss_list, avg_val_loss_list = train(
    model=model, 
    optimizer=optimizer, 
    dl_train=conbined_train_dl, 
    dl_val=combined_val_dl,
    epochs=epochs,
    best_model_path=best_model_path
)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1], which does not match the required output shape [32, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 406, 1], which does not match the required output shape [32, 406, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1002, 1], which does not match the required output shape [32, 1002, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [32, 1003, 1], which does not match the required output shape [32, 1003, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [20, 1], which does not match the required output shape [20, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /home/zekai/miniconda3/envs/eq/lib/python3.11/site-packages/torch/autograd/__init__.py:251: UserWarning: An output with one or more elements was resized since it had shape [20, 1002, 1], which does not match the required output shape [20, 1002, 32]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /opt/conda/conda-bld/pytorch_1695392035891/work/aten/src/ATen/native/Resize.cpp:28.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# 100%|██████████| 200/200 [00:08<00:00, 24.70it/s]

# %%
plt.plot(np.arange(epochs), avg_train_loss_list, label="train loss")
plt.plot(np.arange(epochs), avg_val_loss_list, label="val loss")
plt.xlabel("epochs")
plt.ylabel("nll loss")
plt.title("Training Curve, Pretraining")
plt.legend()
plt.show()

# %%
avg_test_loss = test(model=model, dl_test=test_dl)
# Out:
# avg nll loss:  0.2286933710812882

# %%
model.load_state_dict(torch.load("pretrain_best_model"))
test(model=model, dl_test=white.test.get_dataloader())
# Out:
# avg nll loss:  -88.21128205193413
# -88.21128205193413

# %%
avg nll loss:  0.2286933710812882
# Out:
# avg nll loss:  -408.11922875777003
# -408.11922875777003

# %% [markdown]
# ## Finetune

# %%
batch_size = 32
with open("test_catalog", "rb") as f:
    test_catalog = pickle.load(f)
common_train_dl = test_catalog.train.get_dataloader(batch_size=batch_size)
common_val_dl = test_catalog.val.get_dataloader(batch_size=batch_size)

T = test_catalog.train.sequences[0].t_end
N = np.mean([len(seq) for seq in test_catalog.train.sequences])
tau_mean = T/N

model = RecurrentTPP(
    context_size=32,
    num_components=32,
    rnn_type="LSTM",
    dropout_proba=0.1,
    tau_mean=tau_mean,
    learning_rate=0.005
)
model.to(device)
model.load_state_dict(torch.load("pretrain_best_model"))
model.tau_mean = torch.tensor(tau_mean)

optimizer = torch.optim.AdamW(
        model.parameters(), 
        lr=0.005, 
        betas=(0.99, 0.999), 
        weight_decay=0.005
    )

epochs = 50
best_model_path = "finetune_best_model"

# %%
model, avg_train_loss_list, avg_val_loss_list = train(
    model=model, 
    optimizer=optimizer, 
    dl_train=common_train_dl, 
    dl_val=common_val_dl,
    epochs=epochs,
    best_model_path=best_model_path
)
# Out:
# 100%|██████████| 50/50 [01:55<00:00,  2.31s/it]

# %%
plt.plot(np.arange(epochs), avg_train_loss_list, label="train loss")
plt.plot(np.arange(epochs), avg_val_loss_list, label="val loss")
plt.xlabel("epochs")
plt.ylabel("nll loss")
plt.title("Training Curve, FInetuning")
plt.legend()
plt.show()

# %%
avg_test_loss = test(model=model, dl_test=test_dl)
# Out:
# avg nll loss:  0.15917552852253355

# %%
model.load_state_dict(torch.load("finetune_best_model"))
test(model=model, dl_test=white.test.get_dataloader())
# Out:
# avg nll loss:  -86.33689513736302
# -86.33689513736302

# %%
model.load_state_dict(torch.load("finetune_best_model"))
test(model=model, dl_test=scedc.test.get_dataloader())
# Out:
# avg nll loss:  -408.2804798877665
# -408.2804798877665
